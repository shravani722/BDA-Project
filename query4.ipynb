# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, year, avg, row_number, rank
from pyspark.sql.window import Window

# %%
spark = SparkSession \
    .builder \
    .appName("Databases II") \
    .getOrCreate()

# %%
movie = (spark.read
      .format("csv")
      .option('header', 'true')
      .option("delimiter", ",")
      .option("inferSchema", "true")
      .load("movie.csv")
     )

# %%
rating = (spark.read
      .format("csv")
      .option('header', 'true')
      .option("delimiter", ",")
      .option("inferSchema", "true")
      .load("rating.csv")
     )

# %%
# convert the string column 'timestamp' to timestamp data type
rating = rating.select(col('userId'),
                      col('movieId'),
                      col('rating'),
                      col('timestamp').cast('timestamp').alias('timestamp'))

# %%
# add to 'rating' dataframe an extra column with the year values from column 'timestamp'
rating = rating.select(col('userId'),
                      col('movieId'),
                      col('rating'),
                      col('timestamp'),
                      year(col('timestamp')).alias('yearNum'))

# %%
# execute inner join between 'rating' and 'movie' dataframes
joined = rating.join(movie, ["movieId"], 'inner')

# %%
# create new dataframe 'top' with the columns of dataframe 'joined'
# grouped by the columns 'title' and 'yearNum'
# and find the average rating for each movie, every year
top = joined.select("*").groupby(joined["title"], joined["yearNum"]).agg(avg('rating').alias('average_rating'))

# %%
# create a window partition over the 'yearNum' column
window = Window.partitionBy(top["yearNum"]).orderBy(top["average_rating"].desc(), top["title"].asc())

# %%
# give the sequential row number from 1 to 10, to the result of each window partition
top = top.select('*', row_number().over(window).alias('rank')).filter(col('rank') <= 10)

# %%
# order the results firstly by ascending yearNum and secondly by ascending rank
# and show the results
query4 = top.orderBy(top["yearNum"].asc(), top["rank"].asc()).show(1000)
# Out:
# +--------------------+-------+------------------+----+
# |               title|yearNum|    average_rating|rank|
# +--------------------+-------+------------------+----+
# |Seven (a.k.a. Se7...|   1995|               5.0|   1|
# |Double Life of Ve...|   1995|               4.0|   2|
# |Fish Called Wanda...|   1995|               3.0|   3|
# |   Get Shorty (1995)|   1995|               3.0|   4|
# |Substance of Fire...|   1996| 4.708333333333333|   1|
# |I Can't Sleep (J'...|   1996| 4.538461538461538|   2|
# |Wallace & Gromit:...|   1996| 4.519774011299435|   3|
# |Schindler's List ...|   1996|4.5161642205474015|   4|
# |Somebody is Waiti...|   1996|               4.5|   5|
# |Thieves (Voleurs,...|   1996|               4.5|   6|
# |Wallace & Gromit:...|   1996| 4.488428745432399|   7|
# |Shawshank Redempt...|   1996|4.4781818181818185|   8|
# |Marvin's Room (1996)|   1996| 4.388888888888889|   9|
# |   Casablanca (1942)|   1996| 4.386454183266932|  10|
# |Dangerous Beauty ...|   1997|               5.0|   1|
# |Fallen Angels (Du...|   1997|               5.0|   2|
# |Four Days in Sept...|   1997|               5.0|   3|
# |   Half Baked (1998)|   1997|               5.0|   4|
# |Here Comes Cookie...|   1997|               5.0|   5|
# |Jar, The (Khomreh...|   1997|               5.0|   6|
# |Leading Man, The ...|   1997|               5.0|   7|
# |Six of a Kind (1934)|   1997|               5.0|   8|
# |  Spice World (1997)|   1997|               5.0|   9|
# |     Star Kid (1997)|   1997|               5.0|  10|
# |Frank and Ollie (...|   1998|               5.0|   1|
# |Vive L'Amour (Ai ...|   1998|               5.0|   2|
# |Civil Action, A (...|   1998|               4.5|   3|
# |Parallel Sons (1995)|   1998|               4.5|   4|
# |Saving Private Ry...|   1998| 4.484902309058614|   5|
# |Shawshank Redempt...|   1998| 4.480359147025814|   6|
# |Schindler's List ...|   1998|  4.46749226006192|   7|
# |Wallace & Gromit:...|   1998| 4.422413793103448|   8|
# |One Flew Over the...|   1998| 4.411023622047244|   9|
# |   Casablanca (1942)|   1998|4.3807890222984565|  10|
# |Follow the Bitch ...|   1999|               5.0|   1|
# |Full Speed (À tou...|   1999|               5.0|   2|
# |Hurricane, The (1...|   1999|               5.0|   3|
# |Pharaoh's Army (1...|   1999|               5.0|   4|
# |Someone Else's Am...|   1999|               5.0|   5|
# |  Touki Bouki (1973)|   1999|               5.0|   6|
# |Jar, The (Khomreh...|   1999| 4.666666666666667|   7|
# |       Onegin (1999)|   1999| 4.666666666666667|   8|
# |Paris, France (1993)|   1999| 4.666666666666667|   9|
# |Unvanquished, The...|   1999| 4.589285714285714|  10|
# |And Nobody Weeps ...|   2000|               5.0|   1|
# |    Baby, The (1973)|   2000|               5.0|   2|
# |Brother of Sleep ...|   2000|               5.0|   3|
# |Century of Cinema...|   2000|               5.0|   4|
# |    Garçu, Le (1995)|   2000|               5.0|   5|
# |I Don't Want to T...|   2000|               5.0|   6|
# |It Happened Here ...|   2000|               5.0|   7|
# |Madagascar Skin (...|   2000|               5.0|   8|
# |Mother and Son (M...|   2000|               5.0|   9|
# |Sadness of Sex, T...|   2000|               5.0|  10|
# |Century of Cinema...|   2001|               5.0|   1|
# |Kill Me Later (2001)|   2001|               5.0|   2|
# |Lauderdale (a.k.a...|   2001|               5.0|   3|
# |Proprietor, The (...|   2001|               5.0|   4|
# |Quartier Mozart (...|   2001|               5.0|   5|
# |Raining Stones (1...|   2001|               5.0|   6|
# |Sadness of Sex, T...|   2001|               5.0|   7|
# |    Show, The (1995)|   2001|               5.0|   8|
# |Small Wonders (1995)|   2001|               5.0|   9|
# |Somebody is Waiti...|   2001|               5.0|  10|
# |Asoka (Ashoka the...|   2002|               5.0|   1|
# |  Boys Life 3 (2000)|   2002|               5.0|   2|
# | Desert Winds (1995)|   2002|               5.0|   3|
# |       Mirage (1995)|   2002|               5.0|   4|
# |         More (1998)|   2002|               5.0|   5|
# |Plutonium Circus ...|   2002|               5.0|   6|
# |Relative Fear (1994)|   2002|               5.0|   7|
# |Sadness of Sex, T...|   2002|               5.0|   8|
# |Skin Game, The (1...|   2002|               5.0|   9|
# |        Sonny (2002)|   2002|               5.0|  10|
# |Do You Remember D...|   2003|               5.0|   1|
# |Gate of Heavenly ...|   2003|               5.0|   2|
# |Hellhounds on My ...|   2003|               5.0|   3|
# |Hit the Bank (Vab...|   2003|               5.0|   4|
# |Prisoner of Parad...|   2003|               5.0|   5|
# |Someone Else's Am...|   2003|               5.0|   6|
# |Sonic Outlaws (1995)|   2003|               5.0|   7|
# |Train Ride to Hol...|   2003|               5.0|   8|
# |    Idiot Box (1996)|   2003|              4.75|   9|
# |Cabeza de Vaca (1...|   2003| 4.666666666666667|  10|
# |Amazing Adventure...|   2004|               5.0|   1|
# |Amor brujo, El (L...|   2004|               5.0|   2|
# |Deathmaker, The (...|   2004|               5.0|   3|
# |Designated Mourne...|   2004|               5.0|   4|
# |Hellhounds on My ...|   2004|               5.0|   5|
# | Hotel Rwanda (2004)|   2004|               5.0|   6|
# |Identification of...|   2004|               5.0|   7|
# |Intended, The (2002)|   2004|               5.0|   8|
# |    Love Life (2001)|   2004|               5.0|   9|
# |MC5*: A True Test...|   2004|               5.0|  10|
# |Before the Fall (...|   2005|               5.0|   1|
# |   Dancemaker (1998)|   2005|               5.0|   2|
# |Fear Strikes Out ...|   2005|               5.0|   3|
# |Gate of Heavenly ...|   2005|               5.0|   4|
# |Life Is Rosy (a.k...|   2005|               5.0|   5|
# |Married to It (1991)|   2005|               5.0|   6|
# |My Life and Times...|   2005|               5.0|   7|
# |Not Love, Just Fr...|   2005|               5.0|   8|
# |Paris Was a Woman...|   2005|               5.0|   9|
# |Take Care of My C...|   2005|               5.0|  10|
# |Happiest Milliona...|   2006|               5.0|   1|
# | Joe the King (1999)|   2006|               5.0|   2|
# |         More (1998)|   2006|               5.0|   3|
# |Mother and Son (M...|   2006|               5.0|   4|
# |Photographer (Fot...|   2006|               5.0|   5|
# |    Scorchers (1991)|   2006|               5.0|   6|
# |        Star! (1968)|   2006|               5.0|   7|
# |Three Lives and O...|   2006|               5.0|   8|
# |Twice Upon a Time...|   2006|               5.0|   9|
# |Who's Singin' Ove...|   2006|               5.0|  10|
# |Cabaret Balkan (B...|   2007|               5.0|   1|
# |     Floating (1997)|   2007|               5.0|   2|
# |In the Mirror of ...|   2007|               5.0|   3|
# |   Match, The (1999)|   2007|               5.0|   4|
# |Message to Love: ...|   2007|               5.0|   5|
# |Naked Man, The (1...|   2007|               5.0|   6|
# |Night Crossing (1...|   2007|               5.0|   7|
# |Queen of Hearts (...|   2007|               5.0|   8|
# |Red Dwarf, The (N...|   2007|               5.0|   9|
# |         Rude (1995)|   2007|               5.0|  10|
# |All Passion Spent...|   2008|               5.0|   1|
# |Better Living Thr...|   2008|               5.0|   2|
# |       Bullet (1996)|   2008|               5.0|   3|
# |     Calle 54 (2000)|   2008|               5.0|   4|
# |Family Game, The ...|   2008|               5.0|   5|
# |Fighting Elegy (K...|   2008|               5.0|   6|
# |First Descent (2005)|   2008|               5.0|   7|
# |For a Lost Soldie...|   2008|               5.0|   8|
# |Gas, Food, Lodgin...|   2008|               5.0|   9|
# |   Hav Plenty (1997)|   2008|               5.0|  10|
# |At the Earth's Co...|   2009|               5.0|   1|
# |Between Strangers...|   2009|               5.0|   2|
# |Bridge of Dragons...|   2009|               5.0|   3|
# | C.H.O.M.P.S. (1979)|   2009|               5.0|   4|
# |Cattle Queen of M...|   2009|               5.0|   5|
# |Cheerleaders, The...|   2009|               5.0|   6|
# |Circle of Iron (1...|   2009|               5.0|   7|
# |Confessional, The...|   2009|               5.0|   8|
# |Creeping Flesh, T...|   2009|               5.0|   9|
# |     Dadetown (1995)|   2009|               5.0|  10|
# |Angry Red Planet,...|   2010|               5.0|   1|
# |Baron Blood (Orro...|   2010|               5.0|   2|
# |Barren Lives (Vid...|   2010|               5.0|   3|
# |Between the Devil...|   2010|               5.0|   4|
# | Bikini Beach (1964)|   2010|               5.0|   5|
# |   Blindsight (2006)|   2010|               5.0|   6|
# |Blue Light, The (...|   2010|               5.0|   7|
# |      Bomb It (2007)|   2010|               5.0|   8|
# |Bomb the System (...|   2010|               5.0|   9|
# |Boricua's Bond (2...|   2010|               5.0|  10|
# |All Passion Spent...|   2011|               5.0|   1|
# |All These Women (...|   2011|               5.0|   2|
# |Amour fou, L' (1969)|   2011|               5.0|   3|
# |Another Man's Poi...|   2011|               5.0|   4|
# |       Aprile (1998)|   2011|               5.0|   5|
# |  Balance, La (1982)|   2011|               5.0|   6|
# |        Belly (1998)|   2011|               5.0|   7|
# |Blood of Heroes, ...|   2011|               5.0|   8|
# |Body and Soul (1947)|   2011|               5.0|   9|
# |Ceremony, The (Gi...|   2011|               5.0|  10|
# |Adrenaline Drive ...|   2012|               5.0|   1|
# |America, America ...|   2012|               5.0|   2|
# |       Angela (1995)|   2012|               5.0|   3|
# |Animal Love (Tier...|   2012|               5.0|   4|
# |     Arranged (2007)|   2012|               5.0|   5|
# |Back to the Beach...|   2012|               5.0|   6|
# |   Bad Ronald (1974)|   2012|               5.0|   7|
# |      Ballast (2008)|   2012|               5.0|   8|
# |Bang Boom Bang - ...|   2012|               5.0|   9|
# |Barchester Chroni...|   2012|               5.0|  10|
# |24 7: Twenty Four...|   2013|               5.0|   1|
# |Aces: Iron Eagle ...|   2013|               5.0|   2|
# |Adventures of Mar...|   2013|               5.0|   3|
# |After Innocence (...|   2013|               5.0|   4|
# |Amandla! A Revolu...|   2013|               5.0|   5|
# |Anatomy of Hell (...|   2013|               5.0|   6|
# |      Android (1982)|   2013|               5.0|   7|
# |     Ape, The (1940)|   2013|               5.0|   8|
# |Associate, The (1...|   2013|               5.0|   9|
# |Attack of the Gia...|   2013|               5.0|  10|
# |         1971 (2014)|   2014|               5.0|   1|
# |24 City (Er shi s...|   2014|               5.0|   2|
# |A Girl Walks Home...|   2014|               5.0|   3|
# |      Aakrosh (2010)|   2014|               5.0|   4|
# |   Aashiqui 2 (2013)|   2014|               5.0|   5|
# |Above Suspicion (...|   2014|               5.0|   6|
# |Above and Beyond ...|   2014|               5.0|   7|
# | Acacias, Las (2011)|   2014|               5.0|   8|
# |Adjuster, The (1991)|   2014|               5.0|   9|
# |Afflicted, The (2...|   2014|               5.0|  10|
# |'Round Midnight (...|   2015|               5.0|   1|
# |101 Reykjavik (10...|   2015|               5.0|   2|
# |2019: After the F...|   2015|               5.0|   3|
# |28 Hotel Rooms (2...|   2015|               5.0|   4|
# |9 Souls (Nain sou...|   2015|               5.0|   5|
# |A Blank on the Ma...|   2015|               5.0|   6|
# |A Gun for Jennife...|   2015|               5.0|   7|
# |A Night for Dying...|   2015|               5.0|   8|
# |    Abendland (2011)|   2015|               5.0|   9|
# |According to Gret...|   2015|               5.0|  10|
# +--------------------+-------+------------------+----+

# %%
spark.stop()
